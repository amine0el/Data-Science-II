# %% [markdown]
# # Script to Learn the Modell
#
# Uses the generated features from extraction.csv to train different models and evaluate them.

# %%
#Import Used Libraries:
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import sklearn

# Librosa (the mother of audio files)
import librosa
import librosa.display
import IPython.display as ipd
import warnings
warnings.filterwarnings('ignore')

from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import SGDClassifier, LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.neural_network import MLPClassifier
from xgboost import XGBClassifier, XGBRFClassifier
from xgboost import plot_tree, plot_importance

import sklearn.metrics as metrics
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import RFE

# %%
# Set the Path for the Data and print the folder names (genre):
import os
general_path = './Data'
print(list(os.listdir(f'{general_path}/genres_original/')))
# Out:
# ['.DS_Store', 'blues', 'classical', 'country', 'disco', 'hiphop', 'jazz', 'metal', 'pop', 'reggae', 'rock']

# %% [markdown]
# ### Reading in the Data (extraction.csv)

# %%
data = pd.read_csv(f'{general_path}/extraction.csv')    # Read the .csv with Pandas and save it in a dataframe
data = data.iloc[0:, 4:]  # Drop the columns with are not containing features like directory and name of the song
data.head() # Show the features to check the correct extraction
# Out:
#   genre  length  chroma_stft_mean  chroma_stft_var  rms_mean   rms_var  \
# 0   pop   66150          0.354070         0.092004  0.133745  0.002745
# 1   pop   66150          0.346957         0.089579  0.143777  0.001806
# 2   pop   66150          0.328392         0.090207  0.130174  0.002610
# 3   pop   66150          0.310396         0.079919  0.171010  0.002549
# 4   pop   66150          0.440510         0.085436  0.148661  0.002220
#
#    spectral_centroid_mean  spectral_centroid_var  spectral_bandwidth_mean  \
# 0             3041.383942           7.140194e+05              3126.119651
# 1             2922.334626           1.250350e+06              2960.381766
# 2             2802.174545           7.740314e+05              3067.712826
# 3             2723.966562           9.677586e+05              2968.551682
# 4             2377.343178           8.584688e+05              2897.081914
#
#    spectral_bandwidth_var  ...  mfcc16_mean  mfcc16_var  mfcc17_mean  \
# 0           180625.664149  ...    -4.089583    75.57888    -1.411003
# 1           225852.280494  ...    -9.136294    75.58028    -6.210502
# 2           229109.502454  ...    -2.438187    76.66625    -1.685730
# 3           172274.167333  ...    -0.765207   159.05185    -1.928844
# 4           198226.454488  ...     0.535785    32.92679    -1.269861
#
#    mfcc17_var  mfcc18_mean  mfcc18_var  mfcc19_mean  mfcc19_var  mfcc20_mean  \
# 0   99.614204    -0.176044  120.819310    -0.039866    78.57467    -3.026498
# 1   64.975600    -2.355854   87.215126     0.570278    94.36551     3.037296
# 2  116.244995    -0.341338  114.137760    -0.482767   104.12715    -3.239160
# 3  140.865980    -3.151660   95.238190    -8.257116    86.09109    -8.010163
# 4   46.452496    -0.986701   28.281464    -3.069595    39.76437    -8.417820
#
#    mfcc20_var
# 0   86.393980
# 1  105.467790
# 2  106.196540
# 3  141.839810
# 4   50.494537
#
# [5 rows x 59 columns]

# %% [markdown]
# ### Split Data in Features and Label

# %%
y = data['genre'] # Get genre variable for the Label.
X = data.loc[:, data.columns != 'genre'] #select all columns but not the labels

#### NORMALIZE X: Attention at Usage!! Not needed for XGBoost ####

# Normalize so everything is on the same scale. 

#cols = X.columns
#min_max_scaler = preprocessing.MinMaxScaler()
#np_scaled = min_max_scaler.fit_transform(X)

#new data frame with the new scaled data. 
#X = pd.DataFrame(np_scaled, columns = cols)

# %% [markdown]
# ### Splitting the data into training and testing
#
# * 70% - 30% split

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder() # The label encoder maps the genres to numbers so that they can be processed by the learning algorithm

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
y_train = le.fit_transform(y_train)
y_test = le.fit_transform(y_test)

# %% [markdown]
# ### Model Evaluation with 10 Models

# %%
# Create a function to train the modell and evaluate the performance

# TO DO: Add additional performance measurements variables like F1-Score!
def model_assess(model, title = "Default"):
    model.fit(X_train, y_train) # Train the modell
    preds = model.predict(X_test)   # Make a prediction on all the test data
    #print(confusion_matrix(y_test, preds))
    print('Accuracy', title, ':', round(metrics.accuracy_score(y_test, preds), 5), '\n')    # Compare the results of the prediction with the correct labels
    print('Classification-Report for ', title, ':\n',metrics.classification_report(y_test, preds, digits=4),'\n')

# %% [markdown]
# Creation of the models and evaluation with the "model_acess"-function:

# %%
# Naive Bayes
nb = GaussianNB()
model_assess(nb, "Naive Bayes")

# Stochastic Gradient Descent
sgd = SGDClassifier(max_iter=5000, random_state=0)
model_assess(sgd, "Stochastic Gradient Descent")

# KNN
knn = KNeighborsClassifier(n_neighbors=19)
model_assess(knn, "KNN")

# Decission trees
tree = DecisionTreeClassifier()
model_assess(tree, "Decission trees")

# Random Forest
rforest = RandomForestClassifier(n_estimators=1000, max_depth=10, random_state=0)
model_assess(rforest, "Random Forest")

# Support Vector Machine
svm = SVC(decision_function_shape="ovo")
model_assess(svm, "Support Vector Machine")

# Logistic Regression
lg = LogisticRegression(random_state=0, solver='lbfgs', multi_class='multinomial')
model_assess(lg, "Logistic Regression")

# Neural Nets
nn = MLPClassifier(solver='lbfgs', alpha=1e-5, hidden_layer_sizes=(5000, 10), random_state=1)
model_assess(nn, "Neural Nets")


# Cross Gradient Booster
xgb = XGBClassifier(n_estimators=1000, learning_rate=0.05)
model_assess(xgb, "Cross Gradient Booster")

# Cross Gradient Booster (Random Forest)
xgbrf = XGBRFClassifier(objective= 'multi:softmax')
model_assess(xgbrf, "Cross Gradient Booster (Random Forest)")
# Out:
# Accuracy Naive Bayes : 0.43306
#
# Classification-Report for  Naive Bayes :
#                precision    recall  f1-score   support
#
#            0     0.3867    0.2357    0.2929       297
#            1     0.6513    0.8912    0.7526       285
#            2     0.4000    0.3444    0.3701       302
#            3     0.2993    0.4256    0.3514       289
#            4     0.4863    0.2518    0.3318       282
#            5     0.6264    0.2065    0.3106       276
#            6     0.3270    0.8896    0.4782       308
#            7     0.6920    0.5423    0.6081       319
#            8     0.4379    0.4325    0.4352       326
#            9     0.2830    0.0965    0.1439       311
#
#     accuracy                         0.4331      2995
#    macro avg     0.4590    0.4316    0.4075      2995
# weighted avg     0.4574    0.4331    0.4080      2995
#
#
# Accuracy Stochastic Gradient Descent : 0.13957
#
# Classification-Report for  Stochastic Gradient Descent :
#                precision    recall  f1-score   support
#
#            0     0.0000    0.0000    0.0000       297
#            1     0.8667    0.1368    0.2364       285
#            2     0.0000    0.0000    0.0000       302
#            3     0.1437    0.4256    0.2148       289
#            4     0.0000    0.0000    0.0000       282
#            5     0.1204    0.9094    0.2126       276
#            6     0.5556    0.0162    0.0315       308
#            7     0.0000    0.0000    0.0000       319
#            8     0.0000    0.0000    0.0000       326
#            9     0.0000    0.0000    0.0000       311
#
#     accuracy                         0.1396      2995
#    macro avg     0.1686    0.1488    0.0695      2995
# weighted avg     0.1646    0.1396    0.0661      2995
#
#
# Accuracy KNN : 0.30618
#
# Classification-Report for  KNN :
#                precision    recall  f1-score   support
#
#            0     0.1822    0.1380    0.1571       297
#            1     0.6053    0.7158    0.6559       285
#            2     0.2000    0.2252    0.2118       302
#            3     0.1818    0.2215    0.1997       289
#            4     0.2724    0.2695    0.2709       282
#            5     0.2637    0.2609    0.2623       276
#            6     0.3273    0.4123    0.3649       308
#            7     0.3561    0.3918    0.3731       319
#            8     0.3618    0.3252    0.3425       326
#            9     0.2166    0.1093    0.1453       311
#
#     accuracy                         0.3062      2995
#    macro avg     0.2967    0.3069    0.2984      2995
# weighted avg     0.2968    0.3062    0.2979      2995
#
#
# Accuracy Decission trees : 0.64407
#
# Classification-Report for  Decission trees :
#                precision    recall  f1-score   support
#
#            0     0.5914    0.5993    0.5953       297
#            1     0.8450    0.8035    0.8237       285
#            2     0.5290    0.5132    0.5210       302
#            3     0.5868    0.5848    0.5858       289
#            4     0.6337    0.6809    0.6564       282
#            5     0.6242    0.6739    0.6481       276
#            6     0.7593    0.7987    0.7785       308
#            7     0.7260    0.6646    0.6939       319
#            8     0.6938    0.6534    0.6730       326
#            9     0.4686    0.4791    0.4738       311
#
#     accuracy                         0.6441      2995
#    macro avg     0.6458    0.6451    0.6450      2995
# weighted avg     0.6458    0.6441    0.6444      2995
#
#
# Accuracy Random Forest : 0.79533
#
# Classification-Report for  Random Forest :
#                precision    recall  f1-score   support
#
#            0     0.8060    0.8114    0.8087       297
#            1     0.8904    0.9404    0.9147       285
#            2     0.6897    0.7285    0.7085       302
#            3     0.6867    0.7509    0.7174       289
#            4     0.8745    0.7908    0.8305       282
#            5     0.7900    0.8587    0.8229       276
#            6     0.8333    0.9416    0.8841       308
#            7     0.8677    0.8433    0.8553       319
#            8     0.7398    0.7761    0.7575       326
#            9     0.8000    0.5273    0.6357       311
#
#     accuracy                         0.7953      2995
#    macro avg     0.7978    0.7969    0.7935      2995
# weighted avg     0.7973    0.7953    0.7924      2995
#
#
# Accuracy Support Vector Machine : 0.29316
#
# Classification-Report for  Support Vector Machine :
#                precision    recall  f1-score   support
#
#            0     0.0526    0.0034    0.0063       297
#            1     0.4888    0.7649    0.5964       285
#            2     0.1937    0.2848    0.2306       302
#            3     0.1951    0.2734    0.2277       289
#            4     0.2069    0.0213    0.0386       282
#            5     0.2424    0.1739    0.2025       276
#            6     0.2339    0.4838    0.3153       308
#            7     0.4236    0.4169    0.4202       319
#            8     0.3141    0.4847    0.3812       326
#            9     0.0000    0.0000    0.0000       311
#
#     accuracy                         0.2932      2995
#    macro avg     0.2351    0.2907    0.2419      2995
# weighted avg     0.2353    0.2932    0.2436      2995
#
#
# Accuracy Logistic Regression : 0.29149
#
# Classification-Report for  Logistic Regression :
#                precision    recall  f1-score   support
#
#            0     0.1569    0.0539    0.0802       297
#            1     0.4199    0.8456    0.5611       285
#            2     0.2045    0.1788    0.1908       302
#            3     0.2010    0.1453    0.1687       289
#            4     0.1857    0.1383    0.1585       282
#            5     0.1972    0.3551    0.2536       276
#            6     0.2902    0.4156    0.3418       308
#            7     0.3906    0.4420    0.4147       319
#            8     0.3929    0.3037    0.3426       326
#            9     0.1765    0.0482    0.0758       311
#
#     accuracy                         0.2915      2995
#    macro avg     0.2615    0.2926    0.2588      2995
# weighted avg     0.2637    0.2915    0.2596      2995
#
#
# Accuracy Neural Nets : 0.09649
#
# Classification-Report for  Neural Nets :
#                precision    recall  f1-score   support
#
#            0     0.0000    0.0000    0.0000       297
#            1     0.0000    0.0000    0.0000       285
#            2     0.1110    0.9570    0.1990       302
#            3     0.0000    0.0000    0.0000       289
#            4     0.0000    0.0000    0.0000       282
#            5     0.0000    0.0000    0.0000       276
#            6     0.0000    0.0000    0.0000       308
#            7     0.0000    0.0000    0.0000       319
#            8     0.0000    0.0000    0.0000       326
#            9     0.0000    0.0000    0.0000       311
#
#     accuracy                         0.0965      2995
#    macro avg     0.0111    0.0957    0.0199      2995
# weighted avg     0.0112    0.0965    0.0201      2995
#
#
# Accuracy Cross Gradient Booster : 0.89649
#
# Classification-Report for  Cross Gradient Booster :
#                precision    recall  f1-score   support
#
#            0     0.9064    0.9125    0.9094       297
#            1     0.9377    0.9509    0.9443       285
#            2     0.8055    0.8775    0.8399       302
#            3     0.8976    0.9100    0.9038       289
#            4     0.9167    0.8972    0.9068       282
#            5     0.8696    0.8696    0.8696       276
#            6     0.9209    0.9448    0.9327       308
#            7     0.9224    0.9310    0.9267       319
#            8     0.9320    0.8834    0.9071       326
#            9     0.8601    0.7910    0.8241       311
#
#     accuracy                         0.8965      2995
#    macro avg     0.8969    0.8968    0.8964      2995
# weighted avg     0.8971    0.8965    0.8964      2995
#
#
# Accuracy Cross Gradient Booster (Random Forest) : 0.7379
#
# Classification-Report for  Cross Gradient Booster (Random Forest) :
#                precision    recall  f1-score   support
#
#            0     0.7626    0.7138    0.7374       297
#            1     0.8733    0.9193    0.8957       285
#            2     0.5434    0.7053    0.6138       302
#            3     0.5895    0.6609    0.6232       289
#            4     0.7482    0.7376    0.7429       282
#            5     0.7351    0.8043    0.7682       276
#            6     0.8134    0.9058    0.8571       308
#            7     0.8259    0.8182    0.8220       319
#            8     0.7902    0.6933    0.7386       326
#            9     0.7727    0.4373    0.5585       311
#
#     accuracy                         0.7379      2995
#    macro avg     0.7454    0.7396    0.7357      2995
# weighted avg     0.7465    0.7379    0.7352      2995

# %% [markdown]
# ### Training with XGBoost + Confusion Matrix

# %%
# Final model based on the best results from above:
xgb = XGBClassifier(n_estimators=1000, learning_rate=0.05)
#xgb.fit(X_train, y_train)
#xgb.save_model("xgb_model.txt")     # Save learned model into a .txt-File
xgb.load_model("xgb_model.txt")
preds = xgb.predict(X_test)

print('Accuracy', ':', round(metrics.accuracy_score(y_test, preds), 5), '\n')
print(metrics.classification_report(y_test, preds, digits=4))
print('F1-Score', ':', round(metrics.f1_score(y_test, preds, average='micro'), 5), '\n')
# Confusion Matrix
confusion_matr = metrics.confusion_matrix(y_test, preds)  # Check where there is a mismatch of the genres
plt.figure(figsize = (16, 9))
sns.heatmap(confusion_matr, cmap="Blues", annot=True, 
            xticklabels = ["blues", "classical", "country", "disco", "hiphop", "jazz", "metal", "pop", "reggae", "rock"],
           yticklabels=["blues", "classical", "country", "disco", "hiphop", "jazz", "metal", "pop", "reggae", "rock"]);
plt.savefig("conf matrix")
# Out:
# Accuracy : 0.89649
#
#               precision    recall  f1-score   support
#
#            0     0.9064    0.9125    0.9094       297
#            1     0.9377    0.9509    0.9443       285
#            2     0.8055    0.8775    0.8399       302
#            3     0.8976    0.9100    0.9038       289
#            4     0.9167    0.8972    0.9068       282
#            5     0.8696    0.8696    0.8696       276
#            6     0.9209    0.9448    0.9327       308
#            7     0.9224    0.9310    0.9267       319
#            8     0.9320    0.8834    0.9071       326
#            9     0.8601    0.7910    0.8241       311
#
#     accuracy                         0.8965      2995
#    macro avg     0.8969    0.8968    0.8964      2995
# weighted avg     0.8971    0.8965    0.8964      2995
#
# F1-Score : 0.89649

# %% [markdown]
# ### Feature Importance

# %%
import eli5
from eli5.sklearn import PermutationImportance

perm = PermutationImportance(estimator=xgb, random_state=1) # Check which features are important/how there weight is
perm.fit(X_test, y_test)

eli5.show_weights(estimator=perm, feature_names = X_test.columns.tolist())
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <table class="eli5-weights eli5-feature-importances" style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto;">
#     <thead>
#     <tr style="border: none;">
#         <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;">Weight</th>
#         <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#     </tr>
#     </thead>
#     <tbody>
#
#         <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0512
#
#                     &plusmn; 0.0108
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 rms_var
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 80.24%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0503
#
#                     &plusmn; 0.0051
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 harmony_mean
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 83.96%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0373
#
#                     &plusmn; 0.0050
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 mfcc4_mean
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 84.69%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0349
#
#                     &plusmn; 0.0054
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 chroma_stft_mean
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 86.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0307
#
#                     &plusmn; 0.0062
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 rms_mean
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 86.82%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0282
#
#                     &plusmn; 0.0067
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 harmony_var
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 87.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0276
#
#                     &plusmn; 0.0065
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 tempo
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 87.40%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0264
#
#                     &plusmn; 0.0054
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 spectral_bandwidth_mean
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 87.60%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0258
#
#                     &plusmn; 0.0055
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 mfcc9_mean
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 88.30%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0238
#
#                     &plusmn; 0.0042
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 perceptr_mean
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 89.41%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0206
#
#                     &plusmn; 0.0058
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 mfcc6_mean
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 89.74%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0197
#
#                     &plusmn; 0.0026
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 perceptr_var
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 90.34%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0181
#
#                     &plusmn; 0.0023
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 mfcc7_mean
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 91.33%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0155
#
#                     &plusmn; 0.0044
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 mfcc3_mean
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 91.73%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0145
#
#                     &plusmn; 0.0032
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 mfcc11_mean
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 92.11%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0136
#
#                     &plusmn; 0.0016
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 mfcc1_var
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 92.30%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0131
#
#                     &plusmn; 0.0043
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 mfcc5_mean
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 92.91%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0116
#
#                     &plusmn;
